# %% [markdown]
# # Overfitting and regularization (with ``gluon``)
#
# Now that we've built a [regularized logistic regression model from scratch](regularization-scratch.html), let's make this more efficient with ``gluon``. We recommend that you read that section for a description as to why regularization is a good idea. As always, we begin by loading libraries and some data.
#
# [**REFINED DRAFT - RELEASE STAGE: CATFOOD**]

# %%
from __future__ import print_function
import mxnet as mx
from mxnet import autograd
from mxnet import gluon
import mxnet.ndarray as nd
import numpy as np
ctx = mx.cpu()

# for plotting purposes
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
# Out:
# /usr/local/anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py:46: DeprecationWarning: OpenSSL.rand is deprecated - you should use os.urandom instead
#   import OpenSSL.SSL

# %% [markdown]
# ## The MNIST Dataset

# %%
mnist = mx.test_utils.get_mnist()
num_examples = 1000
batch_size = 64
train_data = mx.gluon.data.DataLoader(
    mx.gluon.data.ArrayDataset(mnist["train_data"][:num_examples],
                               mnist["train_label"][:num_examples].astype(np.float32)), 
                               batch_size, shuffle=True)
test_data = mx.gluon.data.DataLoader(
    mx.gluon.data.ArrayDataset(mnist["test_data"][:num_examples],
                               mnist["test_label"][:num_examples].astype(np.float32)), 
                               batch_size, shuffle=False)

# %% [markdown]
# ## Multiclass Logistic Regression

# %%
net = gluon.nn.Sequential()
with net.name_scope():
    net.add(gluon.nn.Dense(10))

# %% [markdown]
# ## Parameter initialization

# %%
net.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx)

# %% [markdown]
# ## Softmax Cross Entropy Loss

# %%
loss = gluon.loss.SoftmaxCrossEntropyLoss()

# %% [markdown]
# ## Optimizer
#
# By default ``gluon`` tries to keep the coefficients from diverging by using a *weight decay* penalty. So, to get the real overfitting experience we need to switch it off. We do this by passing `'wd': 0.0'` when we instantiate the trainer.

# %%
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.01, 'wd': 0.0})

# %% [markdown]
# ## Evaluation Metric

# %%
def evaluate_accuracy(data_iterator, net, loss_fun):
    acc = mx.metric.Accuracy()
    loss_avg = 0.
    for i, (data, label) in enumerate(data_iterator):
        data = data.as_in_context(ctx).reshape((-1,784))
        label = label.as_in_context(ctx)
        output = net(data)
        loss = loss_fun(output, label) 
        predictions = nd.argmax(output, axis=1)
        acc.update(preds=predictions, labels=label)
        loss_avg = loss_avg*i/(i+1) + nd.mean(loss).asscalar()/(i+1)
    return acc.get()[1], loss_avg

def plot_learningcurves(loss_tr,loss_ts, acc_tr,acc_ts):
    xs = list(range(len(loss_tr)))
    
    f = plt.figure(figsize=(12,6))
    fg1 = f.add_subplot(121)
    fg2 = f.add_subplot(122)
    
    fg1.set_xlabel('epoch',fontsize=14)
    fg1.set_title('Comparing loss functions')
    fg1.semilogy(xs, loss_tr)
    fg1.semilogy(xs, loss_ts)
    fg1.grid(True,which="both")

    fg1.legend(['training loss', 'testing loss'],fontsize=14)
    
    fg2.set_title('Comparing accuracy')
    fg1.set_xlabel('epoch',fontsize=14)
    fg2.plot(xs, acc_tr)
    fg2.plot(xs, acc_ts)
    fg2.grid(True,which="both")
    fg2.legend(['training accuracy', 'testing accuracy'],fontsize=14)

# %% [markdown]
# ## Execute training loop

# %%
epochs = 700
moving_loss = 0.
niter=0

loss_seq_train = []
loss_seq_test = []
acc_seq_train = []
acc_seq_test = []

for e in range(epochs):
    for i, (data, label) in enumerate(train_data):
        data = data.as_in_context(ctx).reshape((-1,784))
        label = label.as_in_context(ctx)
        with autograd.record():
            output = net(data)
            cross_entropy = loss(output, label)
        cross_entropy.backward()
        trainer.step(data.shape[0])
        
        ##########################
        #  Keep a moving average of the losses
        ##########################
        niter +=1
        moving_loss = .99 * moving_loss + .01 * nd.mean(cross_entropy).asscalar()
        est_loss = moving_loss/(1-0.99**niter)
            
    test_accuracy, test_loss = evaluate_accuracy(test_data, net, loss)
    train_accuracy, train_loss = evaluate_accuracy(train_data, net, loss)
    
    # save them for later
    loss_seq_train.append(train_loss)
    loss_seq_test.append(test_loss)
    acc_seq_train.append(train_accuracy)
    acc_seq_test.append(test_accuracy)
    
        
    if e % 20 == 0:
        print("Completed epoch %s. Train Loss: %s, Test Loss %s, Train_acc %s, Test_acc %s" % 
              (e+1, train_loss, test_loss, train_accuracy, test_accuracy))     

## Plotting the learning curves
plot_learningcurves(loss_seq_train,loss_seq_test,acc_seq_train,acc_seq_test)
# Out:
# Completed epoch 1. Train Loss: 2.24794429541, Test Loss 2.24502310157, Train_acc 0.131, Test_acc 0.153
# Completed epoch 21. Train Loss: 0.904282532632, Test Loss 1.10360243171, Train_acc 0.829, Test_acc 0.731
# Completed epoch 41. Train Loss: 0.655910728499, Test Loss 0.872482422739, Train_acc 0.851, Test_acc 0.763
# Completed epoch 61. Train Loss: 0.545609913766, Test Loss 0.768554795533, Train_acc 0.877, Test_acc 0.789
# Completed epoch 81. Train Loss: 0.486287910491, Test Loss 0.707242634147, Train_acc 0.888, Test_acc 0.801
# Completed epoch 101. Train Loss: 0.443434009328, Test Loss 0.665424074978, Train_acc 0.897, Test_acc 0.807
# Completed epoch 121. Train Loss: 0.406683974899, Test Loss 0.635071430355, Train_acc 0.907, Test_acc 0.811
# Completed epoch 141. Train Loss: 0.385134231299, Test Loss 0.611718267202, Train_acc 0.919, Test_acc 0.816
# Completed epoch 161. Train Loss: 0.357472268865, Test Loss 0.593406045809, Train_acc 0.923, Test_acc 0.817
# Completed epoch 181. Train Loss: 0.342519369908, Test Loss 0.57853811048, Train_acc 0.928, Test_acc 0.82
# Completed epoch 201. Train Loss: 0.328039580025, Test Loss 0.566422766075, Train_acc 0.933, Test_acc 0.822
# Completed epoch 221. Train Loss: 0.312212341465, Test Loss 0.556152099743, Train_acc 0.934, Test_acc 0.827
# Completed epoch 241. Train Loss: 0.297499235719, Test Loss 0.547649672255, Train_acc 0.938, Test_acc 0.832
# Completed epoch 261. Train Loss: 0.29058873374, Test Loss 0.540502009913, Train_acc 0.94, Test_acc 0.832
# Completed epoch 281. Train Loss: 0.27984116599, Test Loss 0.534476865083, Train_acc 0.943, Test_acc 0.833
# Completed epoch 301. Train Loss: 0.268900504336, Test Loss 0.528843889013, Train_acc 0.945, Test_acc 0.835
# Completed epoch 321. Train Loss: 0.260278551839, Test Loss 0.523846227676, Train_acc 0.947, Test_acc 0.836
# Completed epoch 341. Train Loss: 0.250951974653, Test Loss 0.519688883796, Train_acc 0.947, Test_acc 0.84
# Completed epoch 361. Train Loss: 0.242600260302, Test Loss 0.516483701766, Train_acc 0.949, Test_acc 0.841
# Completed epoch 381. Train Loss: 0.239161945414, Test Loss 0.513200139627, Train_acc 0.952, Test_acc 0.842
# Completed epoch 401. Train Loss: 0.228990640957, Test Loss 0.510377701372, Train_acc 0.953, Test_acc 0.843
# Completed epoch 421. Train Loss: 0.225142918527, Test Loss 0.507965285331, Train_acc 0.953, Test_acc 0.844
# Completed epoch 441. Train Loss: 0.217495181598, Test Loss 0.505947077647, Train_acc 0.956, Test_acc 0.843
# Completed epoch 461. Train Loss: 0.212638693862, Test Loss 0.503812182695, Train_acc 0.958, Test_acc 0.843
# Completed epoch 481. Train Loss: 0.210611627437, Test Loss 0.5024752561, Train_acc 0.96, Test_acc 0.846
# Completed epoch 501. Train Loss: 0.203857984394, Test Loss 0.501145321876, Train_acc 0.96, Test_acc 0.848
# Completed epoch 521. Train Loss: 0.197498517111, Test Loss 0.499824492261, Train_acc 0.961, Test_acc 0.849
# Completed epoch 541. Train Loss: 0.19498143252, Test Loss 0.498781267554, Train_acc 0.961, Test_acc 0.847
# Completed epoch 561. Train Loss: 0.190293879714, Test Loss 0.497847184539, Train_acc 0.963, Test_acc 0.848
# Completed epoch 581. Train Loss: 0.187418742571, Test Loss 0.497204726562, Train_acc 0.965, Test_acc 0.845
# Completed epoch 601. Train Loss: 0.18718773732, Test Loss 0.496184330434, Train_acc 0.966, Test_acc 0.847
# Completed epoch 621. Train Loss: 0.182216912508, Test Loss 0.495424639434, Train_acc 0.966, Test_acc 0.845
# Completed epoch 641. Train Loss: 0.174278477207, Test Loss 0.495097292587, Train_acc 0.967, Test_acc 0.846
# Completed epoch 661. Train Loss: 0.171194995753, Test Loss 0.494863137603, Train_acc 0.968, Test_acc 0.845
# Completed epoch 681. Train Loss: 0.168342399877, Test Loss 0.494337486103, Train_acc 0.969, Test_acc 0.848

# %% [markdown]
# ## Regularization
#
# Now let's see what this mysterious *weight decay* is all about. We begin with a bit of math. When we add an L2 penalty to the weights we are effectively adding $\frac{\lambda}{2} \|w\|^2$ to the loss. Hence, every time we compute the gradient it gets an additional $\lambda w$ term that is added to $g_t$, since this is the very derivative of the L2 penalty. As a result we end up taking a descent step not in the direction $-\eta g_t$ but rather in the direction $-\eta (g_t + \lambda w)$. This effectively shrinks $w$ at each step by $\eta \lambda w$, thus the name weight decay. To make this work in practice we just need to set the weight decay to something nonzero.

# %%
net.collect_params().initialize(mx.init.Xavier(magnitude=2.24), ctx=ctx, force_reinit=True)
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': 0.01, 'wd': 0.001})

moving_loss = 0.
niter=0
loss_seq_train = []
loss_seq_test = []
acc_seq_train = []
acc_seq_test = []

for e in range(epochs):
    for i, (data, label) in enumerate(train_data):
        data = data.as_in_context(ctx).reshape((-1,784))
        label = label.as_in_context(ctx)
        with autograd.record():
            output = net(data)
            cross_entropy = loss(output, label)
        cross_entropy.backward()
        trainer.step(data.shape[0])
        
        ##########################
        #  Keep a moving average of the losses
        ##########################
        niter +=1
        moving_loss = .99 * moving_loss + .01 * nd.mean(cross_entropy).asscalar()
        est_loss = moving_loss/(1-0.99**niter)
            
    test_accuracy, test_loss = evaluate_accuracy(test_data, net,loss)
    train_accuracy, train_loss = evaluate_accuracy(train_data, net, loss)
    
    # save them for later
    loss_seq_train.append(train_loss)
    loss_seq_test.append(test_loss)
    acc_seq_train.append(train_accuracy)
    acc_seq_test.append(test_accuracy)
    
    if e % 20 == 0:
        print("Completed epoch %s. Train Loss: %s, Test Loss %s, Train_acc %s, Test_acc %s" % 
              (e+1, train_loss, test_loss, train_accuracy, test_accuracy))  
        
## Plotting the learning curves
plot_learningcurves(loss_seq_train,loss_seq_test,acc_seq_train,acc_seq_test)
# Out:
# Completed epoch 1. Train Loss: 2.10255509615, Test Loss 2.11314418912, Train_acc 0.299, Test_acc 0.291
# Completed epoch 21. Train Loss: 0.88655905053, Test Loss 1.09529074654, Train_acc 0.823, Test_acc 0.722
# Completed epoch 41. Train Loss: 0.654385175556, Test Loss 0.87182829529, Train_acc 0.853, Test_acc 0.759
# Completed epoch 61. Train Loss: 0.550441818312, Test Loss 0.76985572651, Train_acc 0.876, Test_acc 0.782
# Completed epoch 81. Train Loss: 0.493713485077, Test Loss 0.708571601659, Train_acc 0.888, Test_acc 0.797
# Completed epoch 101. Train Loss: 0.447215350345, Test Loss 0.667274922132, Train_acc 0.9, Test_acc 0.805
# Completed epoch 121. Train Loss: 0.410582222044, Test Loss 0.636774579063, Train_acc 0.909, Test_acc 0.814
# Completed epoch 141. Train Loss: 0.386884698644, Test Loss 0.614526540041, Train_acc 0.916, Test_acc 0.822
# Completed epoch 161. Train Loss: 0.368769736029, Test Loss 0.596224650741, Train_acc 0.919, Test_acc 0.823
# Completed epoch 181. Train Loss: 0.34846263472, Test Loss 0.581511870027, Train_acc 0.924, Test_acc 0.826
# Completed epoch 201. Train Loss: 0.331691701896, Test Loss 0.569364933297, Train_acc 0.927, Test_acc 0.83
# Completed epoch 221. Train Loss: 0.320072812028, Test Loss 0.559063218534, Train_acc 0.93, Test_acc 0.832
# Completed epoch 241. Train Loss: 0.308212052099, Test Loss 0.550687981769, Train_acc 0.933, Test_acc 0.832
# Completed epoch 261. Train Loss: 0.29602766782, Test Loss 0.543190905824, Train_acc 0.933, Test_acc 0.836
# Completed epoch 281. Train Loss: 0.285776367411, Test Loss 0.536873009056, Train_acc 0.939, Test_acc 0.837
# Completed epoch 301. Train Loss: 0.277480111457, Test Loss 0.53150604479, Train_acc 0.942, Test_acc 0.837
# Completed epoch 321. Train Loss: 0.266580214724, Test Loss 0.526894355193, Train_acc 0.943, Test_acc 0.838
# Completed epoch 341. Train Loss: 0.260108944029, Test Loss 0.522418828681, Train_acc 0.944, Test_acc 0.839
# Completed epoch 361. Train Loss: 0.254064226057, Test Loss 0.519196141511, Train_acc 0.946, Test_acc 0.839
# Completed epoch 381. Train Loss: 0.245155246928, Test Loss 0.516379676759, Train_acc 0.948, Test_acc 0.839
# Completed epoch 401. Train Loss: 0.241382782348, Test Loss 0.512935670093, Train_acc 0.952, Test_acc 0.84
# Completed epoch 421. Train Loss: 0.235853517428, Test Loss 0.510796288028, Train_acc 0.953, Test_acc 0.843
# Completed epoch 441. Train Loss: 0.22866443079, Test Loss 0.508565166965, Train_acc 0.953, Test_acc 0.843
# Completed epoch 461. Train Loss: 0.221952623688, Test Loss 0.506695296615, Train_acc 0.955, Test_acc 0.844
# Completed epoch 481. Train Loss: 0.220566182397, Test Loss 0.504874588922, Train_acc 0.958, Test_acc 0.844
# Completed epoch 501. Train Loss: 0.211428383365, Test Loss 0.503521202132, Train_acc 0.96, Test_acc 0.844
# Completed epoch 521. Train Loss: 0.207704277709, Test Loss 0.501840896904, Train_acc 0.961, Test_acc 0.844
# Completed epoch 541. Train Loss: 0.204107023776, Test Loss 0.500569270924, Train_acc 0.963, Test_acc 0.845
# Completed epoch 561. Train Loss: 0.199745742604, Test Loss 0.499801656231, Train_acc 0.965, Test_acc 0.844
# Completed epoch 581. Train Loss: 0.199791220948, Test Loss 0.498470686376, Train_acc 0.965, Test_acc 0.845
# Completed epoch 601. Train Loss: 0.192798740231, Test Loss 0.497618667781, Train_acc 0.965, Test_acc 0.843
# Completed epoch 621. Train Loss: 0.188888792414, Test Loss 0.496931010857, Train_acc 0.966, Test_acc 0.843
# Completed epoch 641. Train Loss: 0.184361152351, Test Loss 0.496116561815, Train_acc 0.966, Test_acc 0.844
# Completed epoch 661. Train Loss: 0.187212818768, Test Loss 0.49570110254, Train_acc 0.966, Test_acc 0.843
# Completed epoch 681. Train Loss: 0.178404312115, Test Loss 0.495252327994, Train_acc 0.968, Test_acc 0.843

# %% [markdown]
# As we can see, the test accuracy improves a bit. Note that the amount by which it improves actually depends on the amount of weight decay. We recommend that you try and experiment with different extents of weight decay. For instance, a larger weight decay (e.g. $0.01$) will lead to inferior performance, one that's larger still ($0.1$) will lead to terrible results. This is one of the reasons why tuning parameters is quite so important in getting good experimental results in practice.

# %% [markdown]
# ## Next
# [Learning environments](../chapter02_supervised-learning/environment.ipynb)

# %% [markdown]
# For whinges or inquiries, [open an issue on  GitHub.](https://github.com/zackchase/mxnet-the-straight-dope)
